# %% [markdown]
# # Q2
#
# (45%) Please design a neural net to predict network intrusion types for the datasets “train_DefenseSystem.csv” and “test_DefenseSystem.csv.” Please read the dataset description in the file “DefenseSystem_Readme.docx.”
# <br>

# %% [markdown]
# ## About the dataset
# - train_DefenseSystem.csv: a training dataset that contains 5,000 data samples.
# - test_DefenseSystem.csv: a test dataset that contains 1,020 data samples.
# - Target Prediction Field：**event_rule_category** with only two classes: “Access Control” and “Web Attack.”
# <br>
#
# 1.	device_dev_name
# 2.	device_family_name
# 3.	device_hashed_mac
# 4.	device_os_name
# 5.	device_type_name
# 6.	device_vendor_name
# 7.	event_protocol_id: PROTOCOL number (1:ICMP, 6:TCP, 17:UDP,...)
# 8.	event_flow_outbound_or_inbound : When an event was triggered, is it outbound or inbound? (It is used to judge whether it attacked or was attacked)
# 9.	event_role_device_or_router: Is the device where the event was triggered just a device or router?
# 10.	event_role_server_or_client: Is the device where the event was triggered a server or client?
# 11.	event_rule_id
# 12.	event_rule_name
# 13.	event_rule_reference
# 14.	event_rule_severity: severity scale ranges from 1 to 5.
# 15.	event_self_ipv4: Device IP address where the event was triggered. Mostly, it would be a private IP; however, if it is a public IP, it has been obfuscated to avoid possible connections to any real-world IPs and misunderstanding.(IP)
# 16.	event_time
# 17.	router_ip: It is also obfuscated and is only used for indicating same router sources.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  'DefenseSystem_Readme.docx',
#  'model.png',
#  'model1',
#  'model1 loss.jpg',
#  'model2',
#  'model3',
#  'model_res_test.csv',
#  'Q2.ipynb',
#  'Q3_logs',
#  'test_DefenseSystem.csv',
#  'Train2_acc.jpg',
#  'Train2_loss.jpg',
#  'Train3_acc.jpg',
#  'Train3_loss.jpg',
#  'Train_acc.jpg',
#  'train_DefenseSystem.csv',
#  'Train_loss.jpg']

# %%
train=pd.read_csv('train_DefenseSystem.csv')
test=pd.read_csv('test_DefenseSystem.csv')
# train['source']=0
# test['source']=1
train_y=pd.get_dummies(train['event_rule_category'])['Web Attack'].astype('category')
train=train.drop(['event_rule_category',], axis=1)
train_test_con=pd.concat([train,test])
train_test_con=train_test_con.drop(['device_hashed_mac','event_time'], axis=1)

# %%
train_test_con[4999:5003]
# Out:
#             device_dev_name device_family_name device_os_name  \
# 4999                Windows           Computer        Windows
# 0     Nokia Internet Tablet           Handheld          Maemo
# 1                   Windows           Computer        Windows
# 2                   Windows           Computer        Windows
#
#      device_type_name device_vendor_name  event_protocol_id  \
# 4999   Desktop/Laptop    Microsoft Corp.                  6
# 0                 PDA              Maemo                  6
# 1      Desktop/Laptop    Microsoft Corp.                  6
# 2      Desktop/Laptop    Microsoft Corp.                  6
#
#      event_flow_outbound_or_inbound event_role_device_or_router  \
# 4999                       outbound                      device
# 0                          outbound                      device
# 1                          outbound                      device
# 2                          outbound                      device
#
#      event_role_server_or_client  event_rule_id  \
# 4999                      client        1050015
# 0                         client        1056078
# 1                         client        1059684
# 2                         client        1059684
#
#                                         event_rule_name  \
# 4999                       WEB Cross-site Scripting -34
# 0                              WEB Hashtable Collisions
# 1     EXPLOIT Bitcoin/LiteCoin/Dogecoin Mining Activ...
# 2     EXPLOIT Bitcoin/LiteCoin/Dogecoin Mining Activ...
#
#                                    event_rule_reference  event_rule_severity  \
# 4999                       CVE-2011-2133; CVE-2014-4116                    4
# 0     CVE-2011-3414; CVE-2011-5034; CVE-2011-5035; C...                    5
# 1     CVE-2014-unknown; http://mining.bitcoin.cz/str...                    4
# 2     CVE-2014-unknown; http://mining.bitcoin.cz/str...                    4
#
#      event_self_ipv4       router_ip
# 4999   192.168.2.188  207.180.62.141
# 0     192.168.11.142  171.186.84.152
# 1      192.168.2.130    46.80.199.99
# 2       192.168.3.53  167.105.79.243

# %%
train.isnull().sum(axis = 0)
# Out:
# device_dev_name                   0
# device_family_name                0
# device_hashed_mac                 0
# device_os_name                    0
# device_type_name                  0
# device_vendor_name                0
# event_protocol_id                 0
# event_flow_outbound_or_inbound    0
# event_role_device_or_router       0
# event_role_server_or_client       0
# event_rule_id                     0
# event_rule_name                   0
# event_rule_reference              0
# event_rule_severity               0
# event_self_ipv4                   0
# event_time                        0
# router_ip                         0
# dtype: int64

# %%
test.isnull().sum(axis = 0)
# Out:
# device_dev_name                   0
# device_family_name                0
# device_hashed_mac                 0
# device_os_name                    0
# device_type_name                  0
# device_vendor_name                0
# event_protocol_id                 0
# event_flow_outbound_or_inbound    0
# event_role_device_or_router       0
# event_role_server_or_client       0
# event_rule_id                     0
# event_rule_name                   0
# event_rule_reference              0
# event_rule_severity               0
# event_self_ipv4                   0
# event_time                        0
# router_ip                         0
# dtype: int64

# %%
train_test_con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6020 entries, 0 to 1019
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   device_dev_name                 6020 non-null   object
#  1   device_family_name              6020 non-null   object
#  2   device_os_name                  6020 non-null   object
#  3   device_type_name                6020 non-null   object
#  4   device_vendor_name              6020 non-null   object
#  5   event_protocol_id               6020 non-null   int64
#  6   event_flow_outbound_or_inbound  6020 non-null   object
#  7   event_role_device_or_router     6020 non-null   object
#  8   event_role_server_or_client     6020 non-null   object
#  9   event_rule_id                   6020 non-null   int64
#  10  event_rule_name                 6020 non-null   object
#  11  event_rule_reference            6020 non-null   object
#  12  event_rule_severity             6020 non-null   int64
#  13  event_self_ipv4                 6020 non-null   object
#  14  router_ip                       6020 non-null   object
# dtypes: int64(3), object(12)
# memory usage: 752.5+ KB

# %%
train_test_con.describe()
# Out:
#        event_protocol_id  event_rule_id  event_rule_severity
# count        6020.000000   6.020000e+03          6020.000000
# mean            6.420100   1.080949e+06             4.361296
# std             2.116422   3.629858e+04             0.480416
# min             0.000000   1.049802e+06             4.000000
# 25%             6.000000   1.050015e+06             4.000000
# 50%             6.000000   1.056720e+06             4.000000
# 75%             6.000000   1.130593e+06             5.000000
# max            17.000000   1.132896e+06             5.000000

# %%
train_test_con.head()
# Out:
#   device_dev_name device_family_name device_os_name device_type_name  \
# 0      Windows XP           Computer     Windows XP   Desktop/Laptop
# 1         Windows           Computer        Windows   Desktop/Laptop
# 2    Windows 8/10           Computer   Windows 8/10   Desktop/Laptop
# 3         Windows           Computer        Windows   Desktop/Laptop
# 4         Windows           Computer        Windows   Desktop/Laptop
#
#   device_vendor_name  event_protocol_id event_flow_outbound_or_inbound  \
# 0    Microsoft Corp.                  6                       outbound
# 1    Microsoft Corp.                  6                       outbound
# 2    Microsoft Corp.                  6                       outbound
# 3    Microsoft Corp.                  6                       outbound
# 4    Microsoft Corp.                  6                       outbound
#
#   event_role_device_or_router event_role_server_or_client  event_rule_id  \
# 0                      device                      client        1050015
# 1                      device                      client        1130593
# 2                      device                      client        1056078
# 3                      device                      client        1050015
# 4                      device                      client        1050015
#
#                                      event_rule_name  \
# 0                       WEB Cross-site Scripting -34
# 1  WEB Microsoft IIS HTTP.sys Remote Code Executi...
# 2                           WEB Hashtable Collisions
# 3                       WEB Cross-site Scripting -34
# 4                       WEB Cross-site Scripting -34
#
#                                 event_rule_reference  event_rule_severity  \
# 0                       CVE-2011-2133; CVE-2014-4116                    4
# 1                            CVE-2015-1635; MS15-034                    5
# 2  CVE-2011-3414; CVE-2011-5034; CVE-2011-5035; C...                    5
# 3                       CVE-2011-2133; CVE-2014-4116                    4
# 4                       CVE-2011-2133; CVE-2014-4116                    4
#
#   event_self_ipv4       router_ip
# 0   192.168.1.243  161.139.40.242
# 1   192.168.1.133    199.221.3.43
# 2   192.168.1.100    157.2.60.102
# 3     192.168.1.6    51.20.54.170
# 4    192.168.1.44  116.95.157.235

# %%
def find_preprocessing(train_test_con,print_element=False):
    preprocessing={}
    preprocessing['mithght_not_category']=[]
    for i in train_test_con.columns:
        length=len(list(train[i].unique()))
        print('-'*5,i,':',length,'-'*5)

        if length>100:
            preprocessing['mithght_not_category'].append(i)
            length=20
        elif length>20:
            length=20
        if print_element :print(list(train[i].unique()[0:length]))
    return preprocessing
    # print('\t'.join(list(train[i].unique())[0:length]))

def convert2ip_first3(col):
    col=list(col)
    atrr_1=[]
    for i in col:
        a=i.split('.')
        if len(a) ==1:
            a=int('.'.join(i.split(':')[:1]),16)
        else:
            a=int('.'.join(i.split('.')[:1]))
        atrr_1.append(a)
    return atrr_1

def to_category(df,preprocessing):
    for i in preprocessing['type_to_category']:
        df[i] = df[i].astype('category')
    # 所有object to category
    # for i in preprocessing['to_time']:
    #     df[i]=pd.to_datetime(df[i],format="%m/%d/%Y %H:%M")
    #     # for j in range(len(df)):
    #     #       df[i][j]=df[i][j].timestamp()
    #     # df[i] = df[i].astype('float64')
    #     # Timestamp
    #     # raw_data['Mycol'] =  pd.to_datetime(raw_data['Mycol'], format='%d%b%Y:%H:%M:%S.%f')
    for i in list(df.select_dtypes(include=['object']).columns):
        df[i]=df[i].astype('category')
        
def to_ohe(df):
    for i in list(df.select_dtypes(include=['category']).columns):
        df_ohe=pd.get_dummies(df[i])
        df = pd.concat([df, df_ohe],axis=1)
        df = df.drop([i], axis=1)
    
    return df

# %%
# train_test_con['event_time']

# %%
train_preprocessing=find_preprocessing(train_test_con)
train_preprocessing['type_to_category']=['event_rule_severity','event_protocol_id','event_protocol_id','event_rule_id','router_ip','event_self_ipv4']
# train_preprocessing['to_time']=['event_time']
# Out:
# ----- device_dev_name : 44 -----
# ----- device_family_name : 7 -----
# ----- device_os_name : 23 -----
# ----- device_type_name : 16 -----
# ----- device_vendor_name : 26 -----
# ----- event_protocol_id : 3 -----
# ----- event_flow_outbound_or_inbound : 2 -----
# ----- event_role_device_or_router : 2 -----
# ----- event_role_server_or_client : 2 -----
# ----- event_rule_id : 53 -----
# ----- event_rule_name : 53 -----
# ----- event_rule_reference : 38 -----
# ----- event_rule_severity : 2 -----
# ----- event_self_ipv4 : 1100 -----
# ----- router_ip : 3857 -----

# %%
train_preprocessing
# Out:
# {'mithght_not_category': ['event_self_ipv4', 'router_ip'],
#  'type_to_category': ['event_rule_severity',
#   'event_protocol_id',
#   'event_protocol_id',
#   'event_rule_id',
#   'router_ip',
#   'event_self_ipv4']}

# %%
train_preprocessing['mithght_not_category']
# Out:
# ['event_self_ipv4', 'router_ip']

# %%
# train_test_con['device_hashed_mac'].unique() #object

# %%
# print(list(train['event_time'].unique()))

# %%
train_test_con['event_self_ipv4']=convert2ip_first3(train_test_con['event_self_ipv4'])
train_test_con['router_ip']=convert2ip_first3(train_test_con['router_ip'])

# %%
# train_test_con['event_time']

# %%
to_category(train_test_con,train_preprocessing)
train_test_con=to_ohe(train_test_con)

# %%
train_test_con.tail()
# Out:
#       ASUS RT Router  Amazon Kindle  Android 3.0-4.1  Android 4.2-5.1  \
# 1015               0              0                0                0
# 1016               0              0                0                0
# 1017               0              0                0                0
# 1018               0              0                0                0
# 1019               0              0                0                0
#
#       Android 6.0  Apple Watch/iPad Pro  Axis Network Camera  \
# 1015            0                     0                    0
# 1016            0                     0                    0
# 1017            0                     0                    0
# 1018            0                     0                    0
# 1019            0                     0                    0
#
#       Belkin F5D8235-4 v2  BlackBerry  Chromebook  ...  9729  9730  9732  \
# 1015                    0           0           0  ...     0     0     0
# 1016                    0           0           0  ...     0     0     0
# 1017                    0           0           0  ...     0     0     0
# 1018                    0           0           0  ...     0     0     0
# 1019                    0           0           0  ...     0     0     0
#
#       9733  9734  9735  10244  10752  10753  10754
# 1015     0     0     0      0      0      0      0
# 1016     0     0     0      0      0      0      0
# 1017     0     0     0      0      0      0      0
# 1018     0     0     0      0      0      0      0
# 1019     0     0     0      0      0      0      0
#
# [5 rows x 524 columns]

# %%
train_x = train_test_con[:len(train)]
test_x = train_test_con[len(train):]

# %% [markdown]
# # 2.1.
# (30%) Randomly select 80% of the training set as your training set and the rest 20% as your validation set. Use the validation set to design your network structure and choose possible hyper-parameters (try 3 different network structures at least and list all the parameters you may use). You need to report the training and validation accuracy for each network.

# %% [markdown]
# ## train test split

# %%
from sklearn.model_selection import train_test_split

train_x = train_x.values
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y,test_size=0.2, random_state=42)

# %%
train_x.shape
# Out:
# (4000, 524)

# %% [markdown]
# ## model 1

# %%
model=keras.Sequential([layers.Dense(1048,activation='relu',input_shape=(524,),use_bias=True),
                        layers.Dense(512,activation='relu',use_bias=True),
                        layers.Dense(256,activation='relu',use_bias=True),# softmax
                        layers.Dense(128,activation='relu',use_bias=True),
                        layers.Dense(64,activation='relu',use_bias=True),
                        layers.Dense(1,activation='sigmoid',use_bias=False)])

# %%
plot_model(model)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1048)              550200
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               537088
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 64
# =================================================================
# Total params: 1,259,832
# Trainable params: 1,259,832
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
             loss=keras.losses.BinaryCrossentropy(),
            metrics=[keras.metrics.BinaryAccuracy()]
             )

# %%
import os 
model_dir='./model1'

log_dir=os.path.join('Q3_logs','tf_model')
os.makedirs(model_dir)
os.makedirs(log_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21040/2903853621.py in <module>
#       3
#       4 log_dir=os.path.join('Q3_logs','tf_model')
# ----> 5 os.makedirs(model_dir)
#       6 os.makedirs(log_dir)
#
# c:\users\eva\appdata\local\programs\python\python37\lib\os.py in makedirs(name, mode, exist_ok)
#     219             return
#     220     try:
# --> 221         mkdir(name, mode)
#     222     except OSError:
#     223         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] 當檔案已存在時，無法建立該檔案。: './model1'

# %%
model_cbk=keras.callbacks.TensorBoard(log_dir=log_dir)
model_mckp=keras.callbacks.ModelCheckpoint(model_dir+'/Best_model.h5',save_best_only=True)

# %%
train_x.shape
# Out:
# (4000, 524)

# %%
history=model.fit(train_x,train_y,batch_size=1000,epochs=150,
                  validation_data  =  (val_x,val_y),callbacks=[model_cbk,model_mckp]
                 )
# Out:
# Epoch 1/150
# 4/4 [==============================] - 1s 135ms/step - loss: 0.5865 - binary_accuracy: 0.8008 - val_loss: 0.3385 - val_binary_accuracy: 0.9580
# Epoch 2/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1849 - binary_accuracy: 0.9750 - val_loss: 0.0316 - val_binary_accuracy: 0.9940
# Epoch 3/150
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0105 - binary_accuracy: 0.9990 - val_loss: 0.0028 - val_binary_accuracy: 0.9990
# Epoch 4/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2.0795e-04 - binary_accuracy: 1.0000 - val_loss: 0.0014 - val_binary_accuracy: 0.9990
# Epoch 5/150
# 4/4 [==============================] - 0s 22ms/step - loss: 1.7777e-06 - binary_accuracy: 1.0000 - val_loss: 0.0032 - val_binary_accuracy: 0.9990
# Epoch 6/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.4548e-06 - binary_accuracy: 1.0000 - val_loss: 0.0060 - val_binary_accuracy: 0.9980
# Epoch 7/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.6131e-06 - binary_accuracy: 1.0000 - val_loss: 0.0088 - val_binary_accuracy: 0.9980
# Epoch 8/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2930e-06 - binary_accuracy: 1.0000 - val_loss: 0.0106 - val_binary_accuracy: 0.9980
# Epoch 9/150
# 4/4 [==============================] - 0s 15ms/step - loss: 6.4040e-07 - binary_accuracy: 1.0000 - val_loss: 0.0118 - val_binary_accuracy: 0.9980
# Epoch 10/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.4000e-07 - binary_accuracy: 1.0000 - val_loss: 0.0125 - val_binary_accuracy: 0.9980
# Epoch 11/150
# 4/4 [==============================] - ETA: 0s - loss: 1.2104e-07 - binary_accuracy: 1.000 - 0s 15ms/step - loss: 1.6596e-07 - binary_accuracy: 1.0000 - val_loss: 0.0130 - val_binary_accuracy: 0.9980
# Epoch 12/150
# 4/4 [==============================] - 0s 16ms/step - loss: 9.7493e-08 - binary_accuracy: 1.0000 - val_loss: 0.0132 - val_binary_accuracy: 0.9980
# Epoch 13/150
# 4/4 [==============================] - 0s 18ms/step - loss: 7.2812e-08 - binary_accuracy: 1.0000 - val_loss: 0.0133 - val_binary_accuracy: 0.9980
# Epoch 14/150
# 4/4 [==============================] - 0s 16ms/step - loss: 4.9059e-08 - binary_accuracy: 1.0000 - val_loss: 0.0133 - val_binary_accuracy: 0.9980
# Epoch 15/150
# 4/4 [==============================] - 0s 17ms/step - loss: 4.0581e-08 - binary_accuracy: 1.0000 - val_loss: 0.0133 - val_binary_accuracy: 0.9980
# Epoch 16/150
# 4/4 [==============================] - 0s 19ms/step - loss: 3.4503e-08 - binary_accuracy: 1.0000 - val_loss: 0.0133 - val_binary_accuracy: 0.9980
# Epoch 17/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.1529e-08 - binary_accuracy: 1.0000 - val_loss: 0.0133 - val_binary_accuracy: 0.9980
# Epoch 18/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.7510e-08 - binary_accuracy: 1.0000 - val_loss: 0.0132 - val_binary_accuracy: 0.9980
# Epoch 19/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.5556e-08 - binary_accuracy: 1.0000 - val_loss: 0.0132 - val_binary_accuracy: 0.9980
# Epoch 20/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.3488e-08 - binary_accuracy: 1.0000 - val_loss: 0.0131 - val_binary_accuracy: 0.9980
# Epoch 21/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.2143e-08 - binary_accuracy: 1.0000 - val_loss: 0.0130 - val_binary_accuracy: 0.9980
# Epoch 22/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.1014e-08 - binary_accuracy: 1.0000 - val_loss: 0.0130 - val_binary_accuracy: 0.9980
# Epoch 23/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.9797e-08 - binary_accuracy: 1.0000 - val_loss: 0.0129 - val_binary_accuracy: 0.9980
# Epoch 24/150
# 4/4 [==============================] - 0s 23ms/step - loss: 1.9102e-08 - binary_accuracy: 1.0000 - val_loss: 0.0129 - val_binary_accuracy: 0.9980
# Epoch 25/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.8233e-08 - binary_accuracy: 1.0000 - val_loss: 0.0128 - val_binary_accuracy: 0.9980
# Epoch 26/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.7680e-08 - binary_accuracy: 1.0000 - val_loss: 0.0128 - val_binary_accuracy: 0.9980
# Epoch 27/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.6929e-08 - binary_accuracy: 1.0000 - val_loss: 0.0127 - val_binary_accuracy: 0.9980
# Epoch 28/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.6310e-08 - binary_accuracy: 1.0000 - val_loss: 0.0127 - val_binary_accuracy: 0.9980
# Epoch 29/150
# 4/4 [==============================] - 0s 23ms/step - loss: 1.5786e-08 - binary_accuracy: 1.0000 - val_loss: 0.0126 - val_binary_accuracy: 0.9980
# Epoch 30/150
# 4/4 [==============================] - 0s 22ms/step - loss: 1.5189e-08 - binary_accuracy: 1.0000 - val_loss: 0.0126 - val_binary_accuracy: 0.9980
# Epoch 31/150
# 4/4 [==============================] - 0s 21ms/step - loss: 1.4697e-08 - binary_accuracy: 1.0000 - val_loss: 0.0125 - val_binary_accuracy: 0.9980
# Epoch 32/150
# 4/4 [==============================] - 0s 23ms/step - loss: 1.4281e-08 - binary_accuracy: 1.0000 - val_loss: 0.0125 - val_binary_accuracy: 0.9980
# Epoch 33/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3800e-08 - binary_accuracy: 1.0000 - val_loss: 0.0125 - val_binary_accuracy: 0.9980
# Epoch 34/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.3452e-08 - binary_accuracy: 1.0000 - val_loss: 0.0124 - val_binary_accuracy: 0.9980
# Epoch 35/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.3078e-08 - binary_accuracy: 1.0000 - val_loss: 0.0124 - val_binary_accuracy: 0.9980
# Epoch 36/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2644e-08 - binary_accuracy: 1.0000 - val_loss: 0.0123 - val_binary_accuracy: 0.9980
# Epoch 37/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.2274e-08 - binary_accuracy: 1.0000 - val_loss: 0.0123 - val_binary_accuracy: 0.9980
# Epoch 38/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1974e-08 - binary_accuracy: 1.0000 - val_loss: 0.0123 - val_binary_accuracy: 0.9980
# Epoch 39/150
# 4/4 [==============================] - 0s 22ms/step - loss: 1.1690e-08 - binary_accuracy: 1.0000 - val_loss: 0.0122 - val_binary_accuracy: 0.9980
# Epoch 40/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.1360e-08 - binary_accuracy: 1.0000 - val_loss: 0.0122 - val_binary_accuracy: 0.9980
# Epoch 41/150
# 4/4 [==============================] - 0s 22ms/step - loss: 1.1046e-08 - binary_accuracy: 1.0000 - val_loss: 0.0121 - val_binary_accuracy: 0.9980
# Epoch 42/150
# 4/4 [==============================] - 0s 26ms/step - loss: 1.0784e-08 - binary_accuracy: 1.0000 - val_loss: 0.0121 - val_binary_accuracy: 0.9980
# Epoch 43/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.0468e-08 - binary_accuracy: 1.0000 - val_loss: 0.0121 - val_binary_accuracy: 0.9980
# Epoch 44/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.0231e-08 - binary_accuracy: 1.0000 - val_loss: 0.0120 - val_binary_accuracy: 0.9980
# Epoch 45/150
# 4/4 [==============================] - 0s 23ms/step - loss: 9.9761e-09 - binary_accuracy: 1.0000 - val_loss: 0.0120 - val_binary_accuracy: 0.9980
# Epoch 46/150
# 4/4 [==============================] - 0s 19ms/step - loss: 9.7585e-09 - binary_accuracy: 1.0000 - val_loss: 0.0120 - val_binary_accuracy: 0.9980
# Epoch 47/150
# 4/4 [==============================] - 0s 25ms/step - loss: 9.5035e-09 - binary_accuracy: 1.0000 - val_loss: 0.0119 - val_binary_accuracy: 0.9980
# Epoch 48/150
# 4/4 [==============================] - 0s 19ms/step - loss: 9.3132e-09 - binary_accuracy: 1.0000 - val_loss: 0.0119 - val_binary_accuracy: 0.9980
# Epoch 49/150
# 4/4 [==============================] - 0s 22ms/step - loss: 9.0744e-09 - binary_accuracy: 1.0000 - val_loss: 0.0119 - val_binary_accuracy: 0.9980
# Epoch 50/150
# 4/4 [==============================] - 0s 20ms/step - loss: 8.8989e-09 - binary_accuracy: 1.0000 - val_loss: 0.0118 - val_binary_accuracy: 0.9980
# Epoch 51/150
# 4/4 [==============================] - 0s 20ms/step - loss: 8.6984e-09 - binary_accuracy: 1.0000 - val_loss: 0.0118 - val_binary_accuracy: 0.9980
# Epoch 52/150
# 4/4 [==============================] - 0s 23ms/step - loss: 8.5097e-09 - binary_accuracy: 1.0000 - val_loss: 0.0118 - val_binary_accuracy: 0.9980
# Epoch 53/150
# 4/4 [==============================] - 0s 22ms/step - loss: 8.3491e-09 - binary_accuracy: 1.0000 - val_loss: 0.0117 - val_binary_accuracy: 0.9980
# Epoch 54/150
# 4/4 [==============================] - 0s 21ms/step - loss: 8.1380e-09 - binary_accuracy: 1.0000 - val_loss: 0.0117 - val_binary_accuracy: 0.9980
# Epoch 55/150
# 4/4 [==============================] - 0s 22ms/step - loss: 7.9808e-09 - binary_accuracy: 1.0000 - val_loss: 0.0117 - val_binary_accuracy: 0.9980
# Epoch 56/150
# 4/4 [==============================] - 0s 23ms/step - loss: 7.8016e-09 - binary_accuracy: 1.0000 - val_loss: 0.0116 - val_binary_accuracy: 0.9980
# Epoch 57/150
# 4/4 [==============================] - 0s 22ms/step - loss: 3.2808e-09 - binary_accuracy: 1.0000 - val_loss: 0.0104 - val_binary_accuracy: 0.9980
# Epoch 114/150
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2391e-09 - binary_accuracy: 1.0000 - val_loss: 0.0104 - val_binary_accuracy: 0.9980
# Epoch 115/150
# 4/4 [==============================] - 0s 21ms/step - loss: 3.1998e-09 - binary_accuracy: 1.0000 - val_loss: 0.0104 - val_binary_accuracy: 0.9980
# Epoch 116/150
# 4/4 [==============================] - 0s 20ms/step - loss: 3.1634e-09 - binary_accuracy: 1.0000 - val_loss: 0.0103 - val_binary_accuracy: 0.9980
# Epoch 117/150
# 4/4 [==============================] - 0s 19ms/step - loss: 3.1343e-09 - binary_accuracy: 1.0000 - val_loss: 0.0103 - val_binary_accuracy: 0.9980
# Epoch 118/150
# 4/4 [==============================] - 0s 20ms/step - loss: 3.0914e-09 - binary_accuracy: 1.0000 - val_loss: 0.0103 - val_binary_accuracy: 0.9980
# Epoch 119/150
# 4/4 [==============================] - 0s 20ms/step - loss: 3.0663e-09 - binary_accuracy: 1.0000 - val_loss: 0.0103 - val_binary_accuracy: 0.9980
# Epoch 120/150
# 4/4 [==============================] - 0s 21ms/step - loss: 3.0282e-09 - binary_accuracy: 1.0000 - val_loss: 0.0103 - val_binary_accuracy: 0.9980
# Epoch 121/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.9943e-09 - binary_accuracy: 1.0000 - val_loss: 0.0103 - val_binary_accuracy: 0.9980
# Epoch 122/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.9579e-09 - binary_accuracy: 1.0000 - val_loss: 0.0102 - val_binary_accuracy: 0.9980
# Epoch 123/150
# 4/4 [==============================] - 0s 22ms/step - loss: 2.9326e-09 - binary_accuracy: 1.0000 - val_loss: 0.0102 - val_binary_accuracy: 0.9980
# Epoch 124/150
# 4/4 [==============================] - 0s 25ms/step - loss: 2.8984e-09 - binary_accuracy: 1.0000 - val_loss: 0.0102 - val_binary_accuracy: 0.9980
# Epoch 125/150
# 4/4 [==============================] - 0s 25ms/step - loss: 2.8665e-09 - binary_accuracy: 1.0000 - val_loss: 0.0102 - val_binary_accuracy: 0.9980
# Epoch 126/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.8373e-09 - binary_accuracy: 1.0000 - val_loss: 0.0102 - val_binary_accuracy: 0.9980
# Epoch 127/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2.8058e-09 - binary_accuracy: 1.0000 - val_loss: 0.0102 - val_binary_accuracy: 0.9980
# Epoch 128/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.7765e-09 - binary_accuracy: 1.0000 - val_loss: 0.0102 - val_binary_accuracy: 0.9980
# Epoch 129/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.7498e-09 - binary_accuracy: 1.0000 - val_loss: 0.0101 - val_binary_accuracy: 0.9980
# Epoch 130/150
# 4/4 [==============================] - 0s 23ms/step - loss: 2.7196e-09 - binary_accuracy: 1.0000 - val_loss: 0.0101 - val_binary_accuracy: 0.9980
# Epoch 131/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.6936e-09 - binary_accuracy: 1.0000 - val_loss: 0.0101 - val_binary_accuracy: 0.9980
# Epoch 132/150
# 4/4 [==============================] - 0s 22ms/step - loss: 2.6678e-09 - binary_accuracy: 1.0000 - val_loss: 0.0101 - val_binary_accuracy: 0.9980
# Epoch 133/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.6366e-09 - binary_accuracy: 1.0000 - val_loss: 0.0101 - val_binary_accuracy: 0.9980
# Epoch 134/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.6135e-09 - binary_accuracy: 1.0000 - val_loss: 0.0101 - val_binary_accuracy: 0.9980
# Epoch 135/150
# 4/4 [==============================] - 0s 25ms/step - loss: 2.5882e-09 - binary_accuracy: 1.0000 - val_loss: 0.0101 - val_binary_accuracy: 0.9980
# Epoch 136/150
# 4/4 [==============================] - 0s 21ms/step - loss: 2.5612e-09 - binary_accuracy: 1.0000 - val_loss: 0.0100 - val_binary_accuracy: 0.9980
# Epoch 137/150
# 4/4 [==============================] - 0s 21ms/step - loss: 2.5364e-09 - binary_accuracy: 1.0000 - val_loss: 0.0100 - val_binary_accuracy: 0.9980
# Epoch 138/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2.5102e-09 - binary_accuracy: 1.0000 - val_loss: 0.0100 - val_binary_accuracy: 0.9980
# Epoch 139/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.4886e-09 - binary_accuracy: 1.0000 - val_loss: 0.0100 - val_binary_accuracy: 0.9980
# Epoch 140/150
# 4/4 [==============================] - 0s 25ms/step - loss: 2.4635e-09 - binary_accuracy: 1.0000 - val_loss: 0.0100 - val_binary_accuracy: 0.9980
# Epoch 141/150
# 4/4 [==============================] - 0s 30ms/step - loss: 2.4400e-09 - binary_accuracy: 1.0000 - val_loss: 0.0100 - val_binary_accuracy: 0.9980
# Epoch 142/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2.4188e-09 - binary_accuracy: 1.0000 - val_loss: 0.0100 - val_binary_accuracy: 0.9980
# Epoch 143/150
# 4/4 [==============================] - 0s 22ms/step - loss: 2.3967e-09 - binary_accuracy: 1.0000 - val_loss: 0.0099 - val_binary_accuracy: 0.9980
# Epoch 144/150
# 4/4 [==============================] - 0s 16ms/step - loss: 2.3736e-09 - binary_accuracy: 1.0000 - val_loss: 0.0099 - val_binary_accuracy: 0.9980
# Epoch 145/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.3502e-09 - binary_accuracy: 1.0000 - val_loss: 0.0099 - val_binary_accuracy: 0.9980
# Epoch 146/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.3278e-09 - binary_accuracy: 1.0000 - val_loss: 0.0099 - val_binary_accuracy: 0.9980
# Epoch 147/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.3084e-09 - binary_accuracy: 1.0000 - val_loss: 0.0099 - val_binary_accuracy: 0.9980
# Epoch 148/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.2889e-09 - binary_accuracy: 1.0000 - val_loss: 0.0099 - val_binary_accuracy: 0.9980
# Epoch 149/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.2688e-09 - binary_accuracy: 1.0000 - val_loss: 0.0099 - val_binary_accuracy: 0.9980
# Epoch 150/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.2441e-09 - binary_accuracy: 1.0000 - val_loss: 0.0099 - val_binary_accuracy: 0.9980

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
plt.plot(history.history['val_loss'],label='val')
plt.plot(history.history['loss'],label='train')

plt.title('model1 loss')
plt.legend()
plt.savefig('model1 loss.jpg')

# %%
plt.plot(history.history['binary_accuracy'],label='train')
plt.plot(history.history['val_binary_accuracy'],label='val')

plt.title('model1 Acc')
plt.legend()
plt.savefig('Train_acc.jpg')

# %% [markdown]
# ## model

# %%
model_2=keras.Sequential([layers.Dense(512,activation='relu',input_shape=(524,),use_bias=True),
                        # layers.Dense(512,activation='relu',use_bias=True),
                        layers.Dense(256,activation='relu',use_bias=True),# softmax
                        layers.Dense(128,activation='relu',use_bias=True),
                        layers.Dense(64,activation='relu',use_bias=True),
                        layers.Dense(32,activation='relu',use_bias=True),
                        layers.Dense(16,activation='relu',use_bias=True),
                        layers.Dense(1,activation='sigmoid',use_bias=False)])

model_2.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
             loss=keras.losses.BinaryCrossentropy(),
            metrics=[keras.metrics.BinaryAccuracy()]
             )

# %%
plot_model(model_2)

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3716/3470139634.py in <module>
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
import os 
model_dir='./model2'

log_dir=os.path.join('Q3_logs','tf_model2')
os.makedirs(model_dir)
os.makedirs(log_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3716/1632098126.py in <module>
#       3
#       4 log_dir=os.path.join('Q3_logs','tf_model2')
# ----> 5 os.makedirs(model_dir)
#       6 os.makedirs(log_dir)
#
# c:\users\eva\appdata\local\programs\python\python37\lib\os.py in makedirs(name, mode, exist_ok)
#     219             return
#     220     try:
# --> 221         mkdir(name, mode)
#     222     except OSError:
#     223         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] 當檔案已存在時，無法建立該檔案。: './model2'

# %%
model_cbk=keras.callbacks.TensorBoard(log_dir=log_dir)
model_mckp=keras.callbacks.ModelCheckpoint(model_dir+'/Best_model.h5',save_best_only=True)
history_2=model_2.fit(train_x,train_y,batch_size=1000,epochs=150,
                  validation_data  =  (val_x,val_y),callbacks=[model_cbk,model_mckp]
                 )
history_2.history.keys()
# Out:
# Epoch 1/150
# 4/4 [==============================] - 1s 142ms/step - loss: 0.6531 - binary_accuracy: 0.6942 - val_loss: 0.5557 - val_binary_accuracy: 0.8630
# Epoch 2/150
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4851 - binary_accuracy: 0.8988 - val_loss: 0.3504 - val_binary_accuracy: 0.9510
# Epoch 3/150
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2799 - binary_accuracy: 0.9668 - val_loss: 0.1566 - val_binary_accuracy: 0.9950
# Epoch 4/150
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1001 - binary_accuracy: 0.9983 - val_loss: 0.0301 - val_binary_accuracy: 0.9990
# Epoch 5/150
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0137 - binary_accuracy: 1.0000 - val_loss: 0.0028 - val_binary_accuracy: 0.9990
# Epoch 6/150
# 4/4 [==============================] - 0s 32ms/step - loss: 7.3459e-04 - binary_accuracy: 1.0000 - val_loss: 0.0010 - val_binary_accuracy: 0.9990
# Epoch 7/150
# 4/4 [==============================] - 0s 48ms/step - loss: 3.7561e-05 - binary_accuracy: 1.0000 - val_loss: 0.0011 - val_binary_accuracy: 0.9990
# Epoch 8/150
# 4/4 [==============================] - 0s 14ms/step - loss: 6.8921e-06 - binary_accuracy: 1.0000 - val_loss: 0.0012 - val_binary_accuracy: 0.9990
# Epoch 9/150
# 4/4 [==============================] - 0s 18ms/step - loss: 1.9311e-06 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 10/150
# 4/4 [==============================] - 0s 17ms/step - loss: 8.3338e-07 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 11/150
# 4/4 [==============================] - 0s 16ms/step - loss: 4.3753e-07 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 12/150
# 4/4 [==============================] - 0s 17ms/step - loss: 2.7666e-07 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 13/150
# 4/4 [==============================] - 0s 17ms/step - loss: 2.1117e-07 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 14/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.5822e-07 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 15/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2919e-07 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 16/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1295e-07 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 17/150
# 4/4 [==============================] - 0s 25ms/step - loss: 9.7849e-08 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 18/150
# 4/4 [==============================] - 0s 17ms/step - loss: 8.9249e-08 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 19/150
# 4/4 [==============================] - 0s 18ms/step - loss: 8.3786e-08 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 20/150
# 4/4 [==============================] - 0s 17ms/step - loss: 7.9104e-08 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 21/150
# 4/4 [==============================] - 0s 15ms/step - loss: 7.5448e-08 - binary_accuracy: 1.0000 - val_loss: 0.0013 - val_binary_accuracy: 0.9990
# Epoch 22/150
# 4/4 [==============================] - 0s 15ms/step - loss: 7.2600e-08 - binary_accuracy: 1.0000 - val_loss: 0.0012 - val_binary_accuracy: 0.9990
# Epoch 23/150
# 4/4 [==============================] - 0s 18ms/step - loss: 7.0220e-08 - binary_accuracy: 1.0000 - val_loss: 0.0012 - val_binary_accuracy: 0.9990
# Epoch 24/150
# 4/4 [==============================] - 0s 15ms/step - loss: 6.7176e-08 - binary_accuracy: 1.0000 - val_loss: 0.0012 - val_binary_accuracy: 0.9990
# Epoch 25/150
# 4/4 [==============================] - 0s 16ms/step - loss: 6.5276e-08 - binary_accuracy: 1.0000 - val_loss: 0.0012 - val_binary_accuracy: 0.9990
# Epoch 26/150
# 4/4 [==============================] - 0s 19ms/step - loss: 6.3860e-08 - binary_accuracy: 1.0000 - val_loss: 0.0012 - val_binary_accuracy: 0.9990
# Epoch 27/150
# 4/4 [==============================] - 0s 15ms/step - loss: 6.1655e-08 - binary_accuracy: 1.0000 - val_loss: 0.0012 - val_binary_accuracy: 0.9990
# Epoch 28/150
# 4/4 [==============================] - 0s 17ms/step - loss: 5.9827e-08 - binary_accuracy: 1.0000 - val_loss: 0.0012 - val_binary_accuracy: 0.9990
# Epoch 29/150
# 4/4 [==============================] - 0s 18ms/step - loss: 5.8612e-08 - binary_accuracy: 1.0000 - val_loss: 0.0012 - val_binary_accuracy: 0.9990
# Epoch 30/150
# 4/4 [==============================] - 0s 17ms/step - loss: 5.6935e-08 - binary_accuracy: 1.0000 - val_loss: 0.0012 - val_binary_accuracy: 0.9990
# Epoch
# 4/4 [==============================] - 0s 38ms/step - loss: 1.2920e-08 - binary_accuracy: 1.0000 - val_loss: 7.0198e-04 - val_binary_accuracy: 0.9990
# Epoch 142/150
# 4/4 [==============================] - 0s 30ms/step - loss: 1.2817e-08 - binary_accuracy: 1.0000 - val_loss: 6.9964e-04 - val_binary_accuracy: 0.9990
# Epoch 143/150
# 4/4 [==============================] - 0s 23ms/step - loss: 1.2715e-08 - binary_accuracy: 1.0000 - val_loss: 6.9746e-04 - val_binary_accuracy: 0.9990
# Epoch 144/150
# 4/4 [==============================] - 0s 28ms/step - loss: 1.2644e-08 - binary_accuracy: 1.0000 - val_loss: 6.9512e-04 - val_binary_accuracy: 0.9990
# Epoch 145/150
# 4/4 [==============================] - 0s 25ms/step - loss: 1.2547e-08 - binary_accuracy: 1.0000 - val_loss: 6.9288e-04 - val_binary_accuracy: 1.0000
# Epoch 146/150
# 4/4 [==============================] - 0s 27ms/step - loss: 1.2482e-08 - binary_accuracy: 1.0000 - val_loss: 6.9049e-04 - val_binary_accuracy: 1.0000
# Epoch 147/150
# 4/4 [==============================] - 0s 22ms/step - loss: 1.2383e-08 - binary_accuracy: 1.0000 - val_loss: 6.8825e-04 - val_binary_accuracy: 1.0000
# Epoch 148/150
# 4/4 [==============================] - 0s 30ms/step - loss: 1.2306e-08 - binary_accuracy: 1.0000 - val_loss: 6.8598e-04 - val_binary_accuracy: 1.0000
# Epoch 149/150
# 4/4 [==============================] - 0s 31ms/step - loss: 1.2216e-08 - binary_accuracy: 1.0000 - val_loss: 6.8378e-04 - val_binary_accuracy: 1.0000
# Epoch 150/150
# 4/4 [==============================] - 0s 31ms/step - loss: 1.2135e-08 - binary_accuracy: 1.0000 - val_loss: 6.8162e-04 - val_binary_accuracy: 1.0000
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
plt.plot(history_2.history['val_loss'],label='val')
plt.plot(history_2.history['loss'],label='train')

plt.title('Model2 Loss')
plt.legend()
plt.savefig('Train2_loss.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3716/867703635.py in <module>
# ----> 1 plt.plot(history_2.history['val_loss'],label='val')
#       2 plt.plot(history_2.history['loss'],label='train')
#       3
#       4 plt.title('Model2 Loss')
#       5 plt.legend()
#
# NameError: name 'history_2' is not defined

# %%
plt.plot(history_2.history['binary_accuracy'],label='train')
plt.plot(history_2.history['val_binary_accuracy'],label='val')

plt.title('Model2 Acc')
plt.legend()
plt.savefig('Train2_acc.jpg')

# %% [markdown]
# ## model3

# %%
model_3=keras.Sequential([layers.Dense(1048,activation='relu',input_shape=(524,),use_bias=True),
                        layers.Dropout(0.1, seed=5),
                        layers.Dense(512,activation='relu',use_bias=True),
                        layers.Dropout(0.1, seed=5),
                        layers.Dense(256,activation='relu',use_bias=True),# softmax
                        layers.Dropout(0.1, seed=5),
                        layers.Dense(128,activation='relu',use_bias=True),
                        layers.Dropout(0.1, seed=5),
                        layers.Dense(64,activation='relu',use_bias=True),
                        layers.Dropout(0.1, seed=5),
                        layers.Dense(1,activation='sigmoid',use_bias=False)])

model_3.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
             loss=keras.losses.BinaryCrossentropy(),
            metrics=[keras.metrics.BinaryAccuracy()]
             )

# %%
plot_model(model_2)

# %%
import os 
model_dir='./model3'

log_dir=os.path.join('Q3_logs','tf_model3')
os.makedirs(model_dir)
os.makedirs(log_dir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25328/1289687464.py in <module>
#       3
#       4 log_dir=os.path.join('Q3_logs','tf_model3')
# ----> 5 os.makedirs(model_dir)
#       6 os.makedirs(log_dir)
#
# c:\users\eva\appdata\local\programs\python\python37\lib\os.py in makedirs(name, mode, exist_ok)
#     219             return
#     220     try:
# --> 221         mkdir(name, mode)
#     222     except OSError:
#     223         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] 當檔案已存在時，無法建立該檔案。: './model3'

# %%
model_cbk=keras.callbacks.TensorBoard(log_dir=log_dir)
model_mckp=keras.callbacks.ModelCheckpoint(model_dir+'/Best_model.h5',save_best_only=True)
history_3=model_3.fit(train_x,train_y,batch_size=1000,epochs=150,
                  validation_data  =  (val_x,val_y),callbacks=[model_cbk,model_mckp]
                 )
history_3.history.keys()
# Out:
# Epoch 1/150
# 4/4 [==============================] - 1s 156ms/step - loss: 0.5912 - binary_accuracy: 0.7750 - val_loss: 0.3067 - val_binary_accuracy: 0.9410
# Epoch 2/150
# 4/4 [==============================] - 0s 43ms/step - loss: 0.1772 - binary_accuracy: 0.9685 - val_loss: 0.0242 - val_binary_accuracy: 0.9940
# Epoch 3/150
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0133 - binary_accuracy: 0.9962 - val_loss: 0.0018 - val_binary_accuracy: 0.9990
# Epoch 4/150
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0025 - binary_accuracy: 0.9995 - val_loss: 4.7593e-04 - val_binary_accuracy: 1.0000
# Epoch 5/150
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0011 - binary_accuracy: 0.9998 - val_loss: 1.5758e-04 - val_binary_accuracy: 1.0000
# Epoch 6/150
# 4/4 [==============================] - 0s 20ms/step - loss: 1.2560e-06 - binary_accuracy: 1.0000 - val_loss: 4.9571e-05 - val_binary_accuracy: 1.0000
# Epoch 7/150
# 4/4 [==============================] - 0s 18ms/step - loss: 1.0831e-05 - binary_accuracy: 1.0000 - val_loss: 2.7417e-05 - val_binary_accuracy: 1.0000
# Epoch 8/150
# 4/4 [==============================] - 0s 17ms/step - loss: 2.1152e-08 - binary_accuracy: 1.0000 - val_loss: 1.7725e-05 - val_binary_accuracy: 1.0000
# Epoch 9/150
# 4/4 [==============================] - 0s 21ms/step - loss: 8.5106e-09 - binary_accuracy: 1.0000 - val_loss: 1.2968e-05 - val_binary_accuracy: 1.0000
# Epoch 10/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.5469e-08 - binary_accuracy: 1.0000 - val_loss: 1.0434e-05 - val_binary_accuracy: 1.0000
# Epoch 11/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.3061e-10 - binary_accuracy: 1.0000 - val_loss: 9.0520e-06 - val_binary_accuracy: 1.0000
# Epoch 12/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.9665e-10 - binary_accuracy: 1.0000 - val_loss: 8.2122e-06 - val_binary_accuracy: 1.0000
# Epoch 13/150
# 4/4 [==============================] - 0s 21ms/step - loss: 3.3433e-10 - binary_accuracy: 1.0000 - val_loss: 7.6761e-06 - val_binary_accuracy: 1.0000
# Epoch 14/150
# 4/4 [==============================] - 0s 19ms/step - loss: 5.8574e-09 - binary_accuracy: 1.0000 - val_loss: 7.3315e-06 - val_binary_accuracy: 1.0000
# Epoch 15/150
# 4/4 [==============================] - 0s 18ms/step - loss: 5.7512e-10 - binary_accuracy: 1.0000 - val_loss: 7.1053e-06 - val_binary_accuracy: 1.0000
# Epoch 16/150
# 4/4 [==============================] - 0s 18ms/step - loss: 4.2952e-10 - binary_accuracy: 1.0000 - val_loss: 6.9557e-06 - val_binary_accuracy: 1.0000
# Epoch 17/150
# 4/4 [==============================] - 0s 23ms/step - loss: 3.4203e-09 - binary_accuracy: 1.0000 - val_loss: 6.8578e-06 - val_binary_accuracy: 1.0000
# Epoch 18/150
# 4/4 [==============================] - 0s 19ms/step - loss: 2
150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0205e-06 - binary_accuracy: 1.0000 - val_loss: 8.8840e-06 - val_binary_accuracy: 1.0000
# Epoch 38/150
# 4/4 [==============================] - 0s 14ms/step - loss: 2.4196e-11 - binary_accuracy: 1.0000 - val_loss: 9.9104e-06 - val_binary_accuracy: 1.0000
# Epoch 39/150
# 4/4 [==============================] - 0s 19ms/step - loss: 5.1292e-11 - binary_accuracy: 1.0000 - val_loss: 1.0658e-05 - val_binary_accuracy: 1.0000
# Epoch 40/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0006e-10 - binary_accuracy: 1.0000 - val_loss: 1.1186e-05 - val_binary_accuracy: 1.0000
# Epoch 41/150
# 4/4 [==============================] - 0s 20ms/step - loss: 3.3881e-10 - binary_accuracy: 1.0000 - val_loss: 1.1552e-05 - val_binary_accuracy: 1.0000
# Epoch 42/150
# 4/4 [==============================] - 0s 17ms/step - loss: 3.8645e-08 - binary_accuracy: 1.0000 - val_loss: 1.1822e-05 - val_binary_accuracy: 1.0000
# Epoch 43/150
# 4/4 [==============================] - 0s 14ms/step - loss: 4.4382e-11 - binary_accuracy: 1.0000 - val_loss: 1.2053e-05 - val_binary_accuracy: 1.0000
# Epoch 44/150
# 4/4 [==============================] - 0s 14ms/step - loss: 5.1159e-11 - binary_accuracy: 1.0000 - val_loss: 1.2210e-05 - val_binary_accuracy: 1.0000
# Epoch 45/150
# 4/4 [==============================] - 0s 14ms/step - loss: 2.5422e-12 - binary_accuracy: 1.0000 - val_loss: 1.2315e-05 - val_binary_accuracy: 1.0000
# Epoch 46/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0678e-10 - binary_accuracy: 1.0000 - val_loss: 1.2385e-05 - val_binary_accuracy: 1.0000
# Epoch 47/150
# 4/4 [==============================] - 0s 17ms/step - loss: 1.5651e-11 - binary_accuracy: 1.0000 - val_loss: 1.2432e-05 - val_binary_accuracy: 1.0000
# Epoch 48/150
# 4/4 [==============================] - 0s 17ms/step - loss: 3.8070e-11 - binary_accuracy: 1.0000 - val_loss: 1.2464e-05 - val_binary_accuracy: 1.0000
# Epoch 49/150
# 4/4 [==============================] - 0s 14ms/step - loss: 3.2002e-10 - binary_accuracy: 1.0000 - val_loss: 1.2484e-05 - val_binary_accuracy: 1.0000
# Epoch 50/150
# 4/4 [==============================] - 0s 14ms/step - loss: 8.0043e-11 - binary_accuracy: 1.0000 - val_loss: 1.2497e-05 - val_binary_accuracy: 1.0000
# Epoch 51/150
# 4/4 [==============================] - 0s 14ms/step - loss: 2.3616e-12 - binary_accuracy: 1.0000 - val_loss: 1.2506e-05 - val_binary_accuracy: 1.0000
# Epoch 52/150
# 4/4 [==============================] - 0s 14ms/step - loss: 2.8358e-12 - binary_accuracy: 1.0000 - val_loss: 1.2511e-05 - val_binary_accuracy: 1.0000
# Epoch 53/150
# 4/4 [==============================] - 0s 14ms/step - loss: 7.3734e-12 - binary_accuracy: 1.0000 - val_loss: 1.2515e-05 - val_binary_accuracy: 1.0000
# Epoch 54/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0010e-10 - binary_accuracy: 1.0000 - val_loss: 1.2517e-05 - val_binary_accuracy: 1.0000
# Epoch 55/150
# 4/4 [==============================] - 0s 14ms/step - loss: 5.1414e-12 - binary_accuracy: 1.0000 - val_loss: 1.2518e-05 - val_binary_accuracy: 1.0000
# Epoch 56/150
# 4/4 [==============================] - 0s 14ms/step - loss: 3.2131e-12 - binary_accuracy: 1.0000 - val_loss: 1.2519e-05 - val_binary_accuracy: 1.0000
# Epoch 57/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.8865e-10 - binary_accuracy: 1.0000 - val_loss: 1.2519e-05 - val_binary_accuracy: 1.0000
# Epoch 58/150
# 4/4 [==============================] - 0s 14ms/step - loss: 3.1812e-10 - binary_accuracy: 1.0000 - val_loss: 1.2520e-05 - val_binary_accuracy: 1.0000
# Epoch 59/150
# 4/4 [==============================] - 0s 14ms/step - loss: 2.3455e-11 - binary_accuracy: 1.0000 - val_loss: 1.2520e-05 - val_binary_accuracy: 1.0000
# Epoch 60/150
# 4/4 [==============================] - 0s 14ms/step - loss: 4.0495e-11 - binary_accuracy: 1.0000 - val_loss: 1.2520e-05 - val_binary_accuracy: 1.0000
# Epoch 61/150
# 4/4 [==============================] - 0s 14ms/step - loss: 4.8662e-11 - binary_accuracy: 1.0000 - val_loss: 1.2520e-05 - val_binary_accuracy: 1.0000
# Epoch 62/150
# 4/4 [==============================] - 0s 14ms/step - loss: 3.1445e-12 - binary_accuracy: 1.0000 - val_loss: 1.2521e-05 - val_binary_accuracy: 1.0000
# Epoch 63/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.2744e-11 - binary_accuracy: 1.0000 - val_loss: 1.2521e-05 - val_binary_accuracy: 1.0000
# Epoch 64/150
# 4/4 [==============================] - 0s 14ms/step - loss: 4.3266e-10 - binary_accuracy: 1.0000 - val_loss: 1.2521e-05 - val_binary_accuracy: 1.0000
# Epoch 65/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.8169e-11 - binary_accuracy: 1.0000 - val_loss: 1.2521e-05 - val_binary_accuracy: 1.0000
# Epoch 66/150
# 4/4 [==============================] - 0s 14ms/step - loss: 9.5865e-12 - binary_accuracy: 1.0000 - val_loss: 1.2521e-05 - val_binary_accuracy: 1.0000
# Epoch 67/150
# 4/4 [==============================] - 0s 14ms/step - loss: 5.8416e-10 - binary_accuracy: 1.0000 - val_loss: 1.2521e-05 - val_binary_accuracy: 1.0000
# Epoch 68/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.7721e-10 - binary_accuracy: 1.0000 - val_loss: 1.2522e-05 - val_binary_accuracy: 1.0000
# Epoch 69/150
# 4/4 [==============================] - 0s 13ms/step - loss: 2.3992e-12 - binary_accuracy: 1.0000 - val_loss: 1.2523e-05 - val_binary_accuracy: 1.0000
# Epoch 70/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.4384e-10 - binary_accuracy: 1.0000 - val_loss: 1.2523e-05 - val_binary_accuracy: 1.0000
# Epoch 71/150
# 4/4 [==============================] - 0s 14ms/step - loss: 7.8846e-11 - binary_accuracy: 1.0000 - val_loss: 1.2523e-05 - val_binary_accuracy: 1.0000
# Epoch 72/150
# 4/4 [==============================] - 0s 13ms/step - loss: 5.0640e-13 - binary_accuracy: 1.0000 - val_loss: 1.2523e-05 - val_binary_accuracy: 1.0000
# Epoch 73/150
# 4/4 [==============================] - 0s 14ms/step - loss: 3.2756e-12 - binary_accuracy: 1.0000 - val_loss: 1.2523e-05 - val_binary_accuracy: 1.0000
# Epoch 74/150
# 4/4 [==============================] - 0s 14ms/step - loss: 1.3455e-10 - binary_accuracy: 1.0000 - val_loss: 1.2523e-05 - val_binary_accuracy: 1.0000
# Epoch 75/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.1405e-11 - binary_accuracy: 1.0000 - val_loss: 1.2524e-05 - val_binary_accuracy: 1.0000
# Epoch 76/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.5834e-11 - binary_accuracy: 1.0000 - val_loss: 1.2524e-05 - val_binary_accuracy: 1.0000
# Epoch 77/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.0117e-10 - binary_accuracy: 1.0000 - val_loss: 1.2524e-05 - val_binary_accuracy: 1.0000
# Epoch 78/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0314e-11 - binary_accuracy: 1.0000 - val_loss: 1.2524e-05 - val_binary_accuracy: 1.0000
# Epoch 79/150
# 4/4 [==============================] - ETA: 0s - loss: 3.7591e-13 - binary_accuracy: 1.000 - 0s 15ms/step - loss: 8.4112e-11 - binary_accuracy: 1.0000 - val_loss: 1.2524e-05 - val_binary_accuracy: 1.0000
# Epoch 80/150
# 4/4 [==============================] - 0s 20ms/step - loss: 2.7917e-12 - binary_accuracy: 1.0000 - val_loss: 1.2524e-05 - val_binary_accuracy: 1.0000
# Epoch 81/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.5130e-12 - binary_accuracy: 1.0000 - val_loss: 1.2525e-05 - val_binary_accuracy: 1.0000
# Epoch 82/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1913e-09 - binary_accuracy: 1.0000 - val_loss: 1.2531e-05 - val_binary_accuracy: 1.0000
# Epoch 83/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.5959e-11 - binary_accuracy: 1.0000 - val_loss: 1.2535e-05 - val_binary_accuracy: 1.0000
# Epoch 84/150
# 4/4 [==============================] - 0s 15ms/step - loss: 6.0900e-12 - binary_accuracy: 1.0000 - val_loss: 1.2537e-05 - val_binary_accuracy: 1.0000
# Epoch 85/150
# 4/4 [==============================] - 0s 15ms/step - loss: 7.6650e-12 - binary_accuracy: 1.0000 - val_loss: 1.2539e-05 - val_binary_accuracy: 1.0000
# Epoch 86/150
# 4/4 [==============================] - 0s 15ms/step - loss: 8.9472e-11 - binary_accuracy: 1.0000 - val_loss: 1.2539e-05 - val_binary_accuracy: 1.0000
# Epoch 87/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.8348e-11 - binary_accuracy: 1.0000 - val_loss: 1.2540e-05 - val_binary_accuracy: 1.0000
# Epoch 88/150
# 4/4 [==============================] - 0s 23ms/step - loss: 1.6408e-12 - binary_accuracy: 1.0000 - val_loss: 1.2540e-05 - val_binary_accuracy: 1.0000
# Epoch 89/150
# 4/4 [==============================] - 0s 15ms/step - loss: 6.9258e-11 - binary_accuracy: 1.0000 - val_loss: 1.2540e-05 - val_binary_accuracy: 1.0000
# Epoch 90/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.3943e-10 - binary_accuracy: 1.0000 - val_loss: 1.2540e-05 - val_binary_accuracy: 1.0000
# Epoch 91/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.6002e-11 - binary_accuracy: 1.0000 - val_loss: 1.2541e-05 - val_binary_accuracy: 1.0000
# Epoch 92/150
# 4/4 [==============================] - 0s 15ms/step - loss: 5.0586e-11 - binary_accuracy: 1.0000 - val_loss: 1.2541e-05 - val_binary_accuracy: 1.0000
# Epoch 93/150
# 4/4 [==============================] - 0s 15ms/step - loss: 5.1103e-10 - binary_accuracy: 1.0000 - val_loss: 1.2542e-05 - val_binary_accuracy: 1.0000
# Epoch 94/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.0768e-12 - binary_accuracy: 1.0000 - val_loss: 1.2542e-05 - val_binary_accuracy: 1.0000
# Epoch 95/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.2825e-11 - binary_accuracy: 1.0000 - val_loss: 1.2542e-05 - val_binary_accuracy: 1.0000
# Epoch 96/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.0994e-12 - binary_accuracy: 1.0000 - val_loss: 1.2542e-05 - val_binary_accuracy: 1.0000
# Epoch 97/150
# 4/4 [==============================] - 0s 17ms/step - loss: 6.2680e-11 - binary_accuracy: 1.0000 - val_loss: 1.2543e-05 - val_binary_accuracy: 1.0000
# Epoch 98/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.2448e-12 - binary_accuracy: 1.0000 - val_loss: 1.2543e-05 - val_binary_accuracy: 1.0000
# Epoch 99/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.4999e-12 - binary_accuracy: 1.0000 - val_loss: 1.2543e-05 - val_binary_accuracy: 1.0000
# Epoch 100/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.7585e-11 - binary_accuracy: 1.0000 - val_loss: 1.2543e-05 - val_binary_accuracy: 1.0000
# Epoch 101/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.9524e-10 - binary_accuracy: 1.0000 - val_loss: 1.2543e-05 - val_binary_accuracy: 1.0000
# Epoch 102/150
# 4/4 [==============================] - 0s 15ms/step - loss: 8.3887e-09 - binary_accuracy: 1.0000 - val_loss: 1.2563e-05 - val_binary_accuracy: 1.0000
# Epoch 103/150
# 4/4 [==============================] - 0s 18ms/step - loss: 6.1617e-10 - binary_accuracy: 1.0000 - val_loss: 1.2580e-05 - val_binary_accuracy: 1.0000
# Epoch 104/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.8049e-11 - binary_accuracy: 1.0000 - val_loss: 1.2592e-05 - val_binary_accuracy: 1.0000
# Epoch 105/150
# 4/4 [==============================] - 0s 15ms/step - loss: 6.9814e-10 - binary_accuracy: 1.0000 - val_loss: 1.2601e-05 - val_binary_accuracy: 1.0000
# Epoch 106/150
# 4/4 [==============================] - 0s 15ms/step - loss: 6.3112e-11 - binary_accuracy: 1.0000 - val_loss: 1.2607e-05 - val_binary_accuracy: 1.0000
# Epoch 107/150
# 4/4 [==============================] - 0s 15ms/step - loss: 7.3286e-12 - binary_accuracy: 1.0000 - val_loss: 1.2611e-05 - val_binary_accuracy: 1.0000
# Epoch 108/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.4333e-12 - binary_accuracy: 1.0000 - val_loss: 1.2613e-05 - val_binary_accuracy: 1.0000
# Epoch 109/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.5375e-10 - binary_accuracy: 1.0000 - val_loss: 1.2614e-05 - val_binary_accuracy: 1.0000
# Epoch 110/150
# 4/4 [==============================] - 0s 15ms/step - loss: 7.9321e-11 - binary_accuracy: 1.0000 - val_loss: 1.2614e-05 - val_binary_accuracy: 1.0000
# Epoch 111/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.5306e-11 - binary_accuracy: 1.0000 - val_loss: 1.2614e-05 - val_binary_accuracy: 1.0000
# Epoch 112/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.1081e-10 - binary_accuracy: 1.0000 - val_loss: 1.2614e-05 - val_binary_accuracy: 1.0000
# Epoch 113/150
# 4/4 [==============================] - 0s 17ms/step - loss: 7.0418e-12 - binary_accuracy: 1.0000 - val_loss: 1.2614e-05 - val_binary_accuracy: 1.0000
# Epoch 114/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1005e-11 - binary_accuracy: 1.0000 - val_loss: 1.2614e-05 - val_binary_accuracy: 1.0000
# Epoch 115/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.8404e-10 - binary_accuracy: 1.0000 - val_loss: 1.2614e-05 - val_binary_accuracy: 1.0000
# Epoch 116/150
# 4/4 [==============================] - 0s 15ms/step - loss: 8.4265e-12 - binary_accuracy: 1.0000 - val_loss: 1.2615e-05 - val_binary_accuracy: 1.0000
# Epoch 117/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0836e-10 - binary_accuracy: 1.0000 - val_loss: 1.2615e-05 - val_binary_accuracy: 1.0000
# Epoch 118/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.8096e-09 - binary_accuracy: 1.0000 - val_loss: 1.2618e-05 - val_binary_accuracy: 1.0000
# Epoch 119/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2640e-10 - binary_accuracy: 1.0000 - val_loss: 1.2624e-05 - val_binary_accuracy: 1.0000
# Epoch 120/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.0961e-11 - binary_accuracy: 1.0000 - val_loss: 1.2627e-05 - val_binary_accuracy: 1.0000
# Epoch 121/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4507e-10 - binary_accuracy: 1.0000 - val_loss: 1.2629e-05 - val_binary_accuracy: 1.0000
# Epoch 122/150
# 4/4 [==============================] - 0s 15ms/step - loss: 9.6249e-11 - binary_accuracy: 1.0000 - val_loss: 1.2630e-05 - val_binary_accuracy: 1.0000
# Epoch 123/150
# 4/4 [==============================] - 0s 18ms/step - loss: 2.6946e-11 - binary_accuracy: 1.0000 - val_loss: 1.2631e-05 - val_binary_accuracy: 1.0000
# Epoch 124/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.2285e-10 - binary_accuracy: 1.0000 - val_loss: 1.2632e-05 - val_binary_accuracy: 1.0000
# Epoch 125/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0545e-09 - binary_accuracy: 1.0000 - val_loss: 1.2634e-05 - val_binary_accuracy: 1.0000
# Epoch 126/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.7242e-11 - binary_accuracy: 1.0000 - val_loss: 1.2636e-05 - val_binary_accuracy: 1.0000
# Epoch 127/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2126e-10 - binary_accuracy: 1.0000 - val_loss: 1.2637e-05 - val_binary_accuracy: 1.0000
# Epoch 128/150
# 4/4 [==============================] - 0s 15ms/step - loss: 5.1588e-12 - binary_accuracy: 1.0000 - val_loss: 1.2637e-05 - val_binary_accuracy: 1.0000
# Epoch 129/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.5938e-10 - binary_accuracy: 1.0000 - val_loss: 1.2638e-05 - val_binary_accuracy: 1.0000
# Epoch 130/150
# 4/4 [==============================] - 0s 18ms/step - loss: 1.8962e-10 - binary_accuracy: 1.0000 - val_loss: 1.2638e-05 - val_binary_accuracy: 1.0000
# Epoch 131/150
# 4/4 [==============================] - 0s 18ms/step - loss: 8.5470e-11 - binary_accuracy: 1.0000 - val_loss: 1.2638e-05 - val_binary_accuracy: 1.0000
# Epoch 132/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.0262e-12 - binary_accuracy: 1.0000 - val_loss: 1.2638e-05 - val_binary_accuracy: 1.0000
# Epoch 133/150
# 4/4 [==============================] - 0s 19ms/step - loss: 1.2770e-11 - binary_accuracy: 1.0000 - val_loss: 1.2638e-05 - val_binary_accuracy: 1.0000
# Epoch 134/150
# 4/4 [==============================] - 0s 15ms/step - loss: 7.1377e-11 - binary_accuracy: 1.0000 - val_loss: 1.2638e-05 - val_binary_accuracy: 1.0000
# Epoch 135/150
# 4/4 [==============================] - 0s 16ms/step - loss: 1.5717e-11 - binary_accuracy: 1.0000 - val_loss: 1.2638e-05 - val_binary_accuracy: 1.0000
# Epoch 136/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.5791e-11 - binary_accuracy: 1.0000 - val_loss: 1.2638e-05 - val_binary_accuracy: 1.0000
# Epoch 137/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4047e-10 - binary_accuracy: 1.0000 - val_loss: 1.2638e-05 - val_binary_accuracy: 1.0000
# Epoch 138/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.1415e-10 - binary_accuracy: 1.0000 - val_loss: 1.2639e-05 - val_binary_accuracy: 1.0000
# Epoch 139/150
# 4/4 [==============================] - 0s 17ms/step - loss: 3.4746e-11 - binary_accuracy: 1.0000 - val_loss: 1.2640e-05 - val_binary_accuracy: 1.0000
# Epoch 140/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.4033e-11 - binary_accuracy: 1.0000 - val_loss: 1.2641e-05 - val_binary_accuracy: 1.0000
# Epoch 141/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.6272e-12 - binary_accuracy: 1.0000 - val_loss: 1.2641e-05 - val_binary_accuracy: 1.0000
# Epoch 142/150
# 4/4 [==============================] - 0s 15ms/step - loss: 3.4021e-11 - binary_accuracy: 1.0000 - val_loss: 1.2641e-05 - val_binary_accuracy: 1.0000
# Epoch 143/150
# 4/4 [==============================] - 0s 15ms/step - loss: 6.0902e-11 - binary_accuracy: 1.0000 - val_loss: 1.2641e-05 - val_binary_accuracy: 1.0000
# Epoch 144/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.0670e-11 - binary_accuracy: 1.0000 - val_loss: 1.2641e-05 - val_binary_accuracy: 1.0000
# Epoch 145/150
# 4/4 [==============================] - 0s 15ms/step - loss: 5.0923e-12 - binary_accuracy: 1.0000 - val_loss: 1.2641e-05 - val_binary_accuracy: 1.0000
# Epoch 146/150
# 4/4 [==============================] - 0s 15ms/step - loss: 4.0256e-12 - binary_accuracy: 1.0000 - val_loss: 1.2641e-05 - val_binary_accuracy: 1.0000
# Epoch 147/150
# 4/4 [==============================] - 0s 15ms/step - loss: 7.4067e-09 - binary_accuracy: 1.0000 - val_loss: 1.2650e-05 - val_binary_accuracy: 1.0000
# Epoch 148/150
# 4/4 [==============================] - 0s 15ms/step - loss: 1.4213e-11 - binary_accuracy: 1.0000 - val_loss: 1.2678e-05 - val_binary_accuracy: 1.0000
# Epoch 149/150
# 4/4 [==============================] - 0s 15ms/step - loss: 8.4782e-11 - binary_accuracy: 1.0000 - val_loss: 1.2696e-05 - val_binary_accuracy: 1.0000
# Epoch 150/150
# 4/4 [==============================] - 0s 15ms/step - loss: 2.2731e-12 - binary_accuracy: 1.0000 - val_loss: 1.2708e-05 - val_binary_accuracy: 1.0000
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
plt.plot(history_3.history['val_loss'],label='val')
plt.plot(history_3.history['loss'],label='train')

plt.title('model3 loss')
plt.legend()
plt.savefig('Train3_loss.jpg')

# %%
plt.plot(history_3.history['binary_accuracy'],label='train')
plt.plot(history_3.history['val_binary_accuracy'],label='val')

plt.title('model3 acc')
plt.legend()
plt.savefig('Train3_acc.jpg')

# %% [markdown]
# # 2.2.
# (15%) Use your best network (out of 3 at least) to predict the intrusion type for the test set. Please report your results.

# %%
print('model1_loss:{}\tmodel2_loss:{}\tmodel_3loss:{}'.format(history.history['val_loss'][-1],history_2.history['val_loss'][-1],history_3.history['val_loss'][-1]))
# Out:
# model1_loss:0.0013340089935809374	model2_loss:0.0006816205568611622	model_3loss:1.2708395843219478e-05

# %%
pred= model_2.predict(test_x) 
model_res_test=pd.DataFrame( np.where(pred > 0.5, 'Web Attack', 'Access Control'))
# model_res_test_class='Web Attack' if pred>0.5 else 'Access Control'
model_res_test.to_csv('model_res_test.csv')

# %%
model_res_test.head()
# Out:
#                 0
# 0  Access Control
# 1      Web Attack
# 2      Web Attack
# 3      Web Attack
# 4      Web Attack
